# %% [markdown]
# <a href="https://colab.research.google.com/github/rajviishah/Real-Estate-Investment/blob/main/Classification-Techniques/Muller-Classification-Loop-Sarjak.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/Dataset/CMPE 257 - Project/sarjak_new_clean_train.csv")

# %%
dataframe.head()
# Out:
#    Unnamed: 0  MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0           0         3       1         3            3          0          4
# 1           1         3       1         3            3          0          2
# 2           2         3       1         2            3          0          4
# 3           3         3       1         2            3          0          0
# 4           4         3       1         2            3          0          2
#
#    LandSlope  Neighborhood  Condition1  ...  ScreenPorch  PoolArea  MiscVal  \
# 0          0             5           2  ...            0         0        0
# 1          0            24           1  ...            0         0        0
# 2          0             5           2  ...            0         0        0
# 3          0             6           2  ...            0         0        0
# 4          0            15           2  ...            0         0        0
#
# ...

# %%
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'MSZoning', 'Street', 'LotShape', 'LandContour',
#        'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
#        'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl',
#        'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond',
#        'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical',
#        'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'SaleType',
#        'SaleCondition', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd',
# ...

# %%
dataframe = dataframe.drop(['Unnamed: 0'], axis = 1)
dataframe
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0            3       1         3            3          0          4
# 1            3       1         3            3          0          2
# 2            3       1         2            3          0          4
# 3            3       1         2            3          0          0
# 4            3       1         2            3          0          2
# ...        ...     ...       ...          ...        ...        ...
# 1455         3       1         3            3          0          4
# 1456         3       1         3            3          0          4
# 1457         3       1         3            3          0          4
# 1458         3       1         3            3          0          4
# 1459         3       1         3            3          0          4
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  ScreenPorch  \
# 0             0             5           2           2  ...            0
# ...

# %%
X_train = dataframe.drop(['BldgType'], axis=1)
y_train = dataframe['BldgType']

# %%
normalized_X = (X_train-X_train.min())/(X_train.max()-X_train.min())
normalized_X
# Out:
#       MSZoning  Street  LotShape  LandContour  Utilities  LotConfig  \
# 0         0.75     1.0  1.000000          1.0        0.0        1.0
# 1         0.75     1.0  1.000000          1.0        0.0        0.5
# 2         0.75     1.0  0.666667          1.0        0.0        1.0
# 3         0.75     1.0  0.666667          1.0        0.0        0.0
# 4         0.75     1.0  0.666667          1.0        0.0        0.5
# ...        ...     ...       ...          ...        ...        ...
# 1455      0.75     1.0  1.000000          1.0        0.0        1.0
# 1456      0.75     1.0  1.000000          1.0        0.0        1.0
# 1457      0.75     1.0  1.000000          1.0        0.0        1.0
# 1458      0.75     1.0  1.000000          1.0        0.0        1.0
# 1459      0.75     1.0  1.000000          1.0        0.0        1.0
#
#       LandSlope  Neighborhood  Condition1  Condition2  ...  ScreenPorch  \
# 0           0.0      0.208333       0.250    0.285714  ...          0.0
# ...

# %%
#split the features and labels into  train and test data
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y_train, test_size=0.2, random_state=1)

# %%
names = ["Decision Tree", "Random Forest", "Logistic Regression", "Support Vector Machines", "Naive Bayes", "k Nearest Neighbors"]

# %%
classifiers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(max_depth=2, random_state=0),
    LogisticRegression(random_state=0),
    SVC(gamma='auto'),
    GaussianNB(),
    KNeighborsClassifier(n_neighbors=3)
]

# %%
max_score = 0.0
max_class = ''
# iterate over classifiers
for name, clf in zip(names, classifiers):
    start_time = time.time()
    clf.fit(X_train, y_train)
    score = 100.0 * clf.score(X_test, y_test)
    print('Classifier = %s, Score (test, accuracy) = %.2f,' %(name, score), 'Training time = %.2f seconds' % (time.time() - start_time))
    
    if score > max_score:
        clf_best = clf
        max_score = score
        max_class = name
# Out:
# Classifier = Decision Tree, Score (test, accuracy) = 97.60, Training time = 0.01 seconds
# Classifier = Random Forest, Score (test, accuracy) = 84.25, Training time = 0.20 seconds
# Classifier = Logistic Regression, Score (test, accuracy) = 95.55, Training time = 0.21 seconds
# Classifier = Support Vector Machines, Score (test, accuracy) = 84.25, Training time = 0.12 seconds
# Classifier = Naive Bayes, Score (test, accuracy) = 18.49, Training time = 0.01 seconds
# Classifier = k Nearest Neighbors, Score (test, accuracy) = 89.73, Training time = 0.03 seconds
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
print('Best --> Classifier = %s, Score (test, accuracy) = %.2f' %(max_class, max_score))
#plot the output of the various algorithms
# Out:
# Best --> Classifier = Decision Tree, Score (test, accuracy) = 97.60

# %% [markdown]
# - We are trying to implementation of classification algorithms on mutli-label feature.
#
# - Instead of keeping numerical values of features - BldgType, we can convert it to binary classification problem. How? Type of building based on input user preference - Detached/Semi-detached.
#
# - This can help in getting house quality by entering some features like Sales Price. Assuming, the user enters the house budget and location, he/she can get an idea about the building type to look for.
