# %% [markdown]
# <a href="https://colab.research.google.com/github/rajviishah/Real-Estate-Investment/blob/main/Classification-Techniques/Muller-Classification-Loop-Rajvi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
dataframe = pd.read_csv("/content/drive/MyDrive/CMPE 257 - Project/new_clean_train.csv")

# %%
dataframe.head()
# Out:
#    Unnamed: 0  LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  \
# 0           0         3          4          2         4         2
# 1           1         3          2          2         4         2
# 2           2         2          4          2         4         2
# 3           3         2          2          2         2         4
# 4           4         2          4          2         4         2
#
#    BsmtExposure  BsmtFinType1  BsmtFinType2  HeatingQC  ...  ScreenPorch  \
# 0             2             6             1          4  ...            0
# 1             4             5             1          4  ...            0
# 2             2             6             1          4  ...            0
# 3             2             5             1          4  ...            0
# 4             3             6             1          4  ...            0
#
#    PoolArea  MiscVal  MoSold  YrSold  SalePrice  Age_House  TotalBsmtBath  \
# ...

# %%
dataframe.columns
# Out:
# Index(['Unnamed: 0', 'LotShape', 'ExterQual', 'ExterCond', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'HeatingQC',
#        ...
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice',
#        'Age_House', 'TotalBsmtBath', 'TotalBath', 'TotalSA'],
#       dtype='object', length=232)

# %%
dataframe = dataframe.drop(['Unnamed: 0'], axis = 1)
dataframe
# Out:
#       LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  \
# 0            3          4          2         4         2             2
# 1            3          2          2         4         2             4
# 2            2          4          2         4         2             2
# 3            2          2          2         2         4             2
# 4            2          4          2         4         2             3
# ...        ...        ...        ...       ...       ...           ...
# 1455         3          2          2         4         2             2
# 1456         3          2          2         4         2             2
# 1457         3          4          4         2         4             2
# 1458         3          2          2         2         2             2
# 1459         3          4          2         2         2             2
#
#       BsmtFinType1  BsmtFinType2  HeatingQC  CentralAir  ...  ScreenPorch  \
# ...

# %%
X_train = dataframe.drop(['OverallQual'], axis=1)
y_train = dataframe['OverallQual']

# %%
normalized_X = (X_train-X_train.min())/(X_train.max()-X_train.min())
normalized_X
# Out:
#       LotShape  ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  \
# 0     1.000000   1.000000   0.333333       1.0       0.5          0.50
# 1     1.000000   0.333333   0.333333       1.0       0.5          1.00
# 2     0.666667   1.000000   0.333333       1.0       0.5          0.50
# 3     0.666667   0.333333   0.333333       0.5       1.0          0.50
# 4     0.666667   1.000000   0.333333       1.0       0.5          0.75
# ...        ...        ...        ...       ...       ...           ...
# 1455  1.000000   0.333333   0.333333       1.0       0.5          0.50
# 1456  1.000000   0.333333   0.333333       1.0       0.5          0.50
# 1457  1.000000   1.000000   1.000000       0.5       1.0          0.50
# 1458  1.000000   0.333333   0.333333       0.5       0.5          0.50
# 1459  1.000000   1.000000   0.333333       0.5       0.5          0.50
#
#       BsmtFinType1  BsmtFinType2  HeatingQC  CentralAir  ...  ScreenPorch  \
# ...

# %%
#split the features and labels into  train and test data
X_train, X_test, y_train, y_test = train_test_split(normalized_X, y_train, test_size=0.2, random_state=1)

# %%
names = ["Decision Tree", "Random Forest", "Logistic Regression", "Support Vector Machines", "Naive Bayes", "k Nearest Neighbors"]

# %%
classifiers = [
    DecisionTreeClassifier(),
    RandomForestClassifier(max_depth=2, random_state=0),
    LogisticRegression(random_state=0),
    SVC(gamma='auto'),
    GaussianNB(),
    KNeighborsClassifier(n_neighbors=3)

]

# %%
max_score = 0.0
max_class = ''
# iterate over classifiers
for name, clf in zip(names, classifiers):
    start_time = time.time()
    clf.fit(X_train, y_train)
    score = 100.0 * clf.score(X_test, y_test)
    print('Classifier = %s, Score (test, accuracy) = %.2f,' %(name, score), 'Training time = %.2f seconds' % (time.time() - start_time))
    
    if score > max_score:
        clf_best = clf
        max_score = score
        max_class = name
# Out:
# Classifier = Decision Tree, Score (test, accuracy) = 46.58, Training time = 0.05 seconds
# Classifier = Random Forest, Score (test, accuracy) = 48.97, Training time = 0.24 seconds
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:818: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG,
# Classifier = Logistic Regression, Score (test, accuracy) = 53.77, Training time = 0.56 seconds
# Classifier = Support Vector Machines, Score (test, accuracy) = 49.66, Training time = 0.41 seconds
# ...

# %%
print('Best --> Classifier = %s, Score (test, accuracy) = %.2f' %(max_class, max_score))
#plot the output of the various algorithms
# Out:
# Best --> Classifier = Logistic Regression, Score (test, accuracy) = 53.77

# %% [markdown]
# - We are trying to implementation of classification algorithms on mutli-label feature.
#
# - Instead of keeping numerical values of features - OverallQual, we can convert it to binary classification problem. How? OverallQual > 5 -> Good quality; OverallQual < 5 -> Not Good quality.
#
# - This can help in getting house quality by entering some features like Sales Price. Assuming, the user enters the house budget and location, he/she can get an idea about the house quality.
